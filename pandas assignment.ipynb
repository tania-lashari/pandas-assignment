# %%
import numpy as np

# %%
import pandas as pd

# %%
state0 = pd.read_csv('states0.csv')
state1 = pd.read_csv('states1.csv')
state2 = pd.read_csv('states2.csv')
state3 = pd.read_csv('states3.csv')
state4 = pd.read_csv('states4.csv')
state5 = pd.read_csv('states5.csv')
state6 = pd.read_csv('states6.csv')
state7 = pd.read_csv('states7.csv')
state8 = pd.read_csv('states8.csv')
state9 = pd.read_csv('states9.csv')

# %%
from pandas import DataFrame

# %%
data0 = pd.DataFrame(state0)
data1 = pd.DataFrame(state1)
data2 = pd.DataFrame(state2)
data3 = pd.DataFrame(state3)
data4 = pd.DataFrame(state4)
data5 = pd.DataFrame(state5)
data6 = pd.DataFrame(state6)
data7 = pd.DataFrame(state7)
data8 = pd.DataFrame(state8)
data9 = pd.DataFrame(state9)

# %%
data = pd.concat([data0,data1,data2,data3,data4,data5,data6,data7,data8,data9], sort = False)

# %%
us_census = pd.DataFrame(data)

# %%
us_census
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
import re

# %%
us_census['Income']
# Out:
# 0     $43296.35860306644
# 1     $70354.74390243902
# 2     $54207.82095490716
# 3     $41935.63396778917
# 4     $67264.78230266465
# 5    $64657.801787164906
# 0    $64657.801787164906
# 1      $76146.5605875153
# 2     $61827.97663551402
# 3     $75466.36363636363
# 4    $50690.194986743794
# 5     $50811.08205128205
# 0     $50811.08205128205
# 1     $73264.42628205128
# 2     $48017.31543624161
# 3     $59587.04887459807
# 4     $48616.22784810127
# 5     $53017.75304136253
# 0     $53017.75304136253
# 1    $53885.612648221344
# 2     $45285.80253623189
# 3     $44957.99376114082
# 4     $49181.97435897436
# 5     $78765.40072463769
# 0     $78765.40072463769
# 1     $72838.93672627235
# 2     $51201.83003663004
# 3       $62820.833959429
# 4     $38909.91920731707
# 5     $49763.98772563177
# 0     $49763.98772563177
# 1    $47645.682835820895
# 2    $55916.469696969696
# 3    $55526.525073746314
# 4      $68728.8595890411
# 5     $76581.08341708542
# 0     $76581.08341708542
# ...

# %%
dd = us_census['Income'].astype(str)

# %%
Income = pd.to_numeric(us_census['Income'].replace('[^0-9\.-]', '', regex=True))

# %%
us_census['Income'] = Income

# %%
us_census
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
GenderPop = us_census['GenderPop'].str.split('_',n=1,expand=True)
GenderPop
# Out:
#            0          1
# 0   2341093M   2489527F
# 1    384160M    349215F
# 2   3299088M   3342840F
# 3   1451913M   1506295F
# 4  19087135M  19334329F
# 5   2648667M   2630239F
# 0   2648667M   2630239F
# 1   1751607M   1841615F
# 2    448413M    478041F
# 3    306674M    340810F
# 4   9600009M  10045763F
# 5   4883331M   5123362F
# 0   4883331M   5123362F
# 1    709871M    696428F
# 2    810464M    806083F
# 3   6316899M   6556862F
# 4   3235263M   3333382F
# 5   1534595M   1558931F
# 0   1534595M   1558931F
# 1   1439862M   1453125F
# 2   2164208M   2233145F
# 3   2261156M   2364097F
# 4    650081M    679019F
# 5   2872643M          F
# 0   2872643M          F
# 1   3249650M   3455936F
# 2   4861973M   5038598F
# 3   2692166M   2727005F
# 4   1451723M   1536358F
# 5   2964003M   3081445F
# 0   2964003M   3081445F
# 1    510163M          F
# 2    929606M    939759F
# 3   1407735M   1390901F
# 4    653484M    670717F
# 5   4343027M   4561386F
# 0   4343027M   4561386F
# ...

# %%
split = GenderPop.rename(columns = {0:'male',1:'femal'})

# %%
split
# Out:
#         male      femal
# 0   2341093M   2489527F
# 1    384160M    349215F
# 2   3299088M   3342840F
# 3   1451913M   1506295F
# 4  19087135M  19334329F
# 5   2648667M   2630239F
# 0   2648667M   2630239F
# 1   1751607M   1841615F
# 2    448413M    478041F
# 3    306674M    340810F
# 4   9600009M  10045763F
# 5   4883331M   5123362F
# 0   4883331M   5123362F
# 1    709871M    696428F
# 2    810464M    806083F
# 3   6316899M   6556862F
# 4   3235263M   3333382F
# 5   1534595M   1558931F
# 0   1534595M   1558931F
# 1   1439862M   1453125F
# 2   2164208M   2233145F
# 3   2261156M   2364097F
# 4    650081M    679019F
# 5   2872643M          F
# 0   2872643M          F
# 1   3249650M   3455936F
# 2   4861973M   5038598F
# 3   2692166M   2727005F
# 4   1451723M   1536358F
# 5   2964003M   3081445F
# 0   2964003M   3081445F
# 1    510163M          F
# 2    929606M    939759F
# 3   1407735M   1390901F
# 4    653484M    670717F
# 5   4343027M   4561386F
# 0   4343027M   4561386F
# ...

# %%
male_numeric = pd.to_numeric(split['male'].replace('[^0-9\.-]', '', regex=True))
female_numeric = pd.to_numeric(split['femal'].replace('[^0-9\.-]', '', regex=True))

# %%
female_numeric
# Out:
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5           NaN
# 0           NaN
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1           NaN
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 0     1444150.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(female_numeric,df)

# %%
us_census['TotalPop']-male_numeric
# Out:
# 0     2489527
# 1      349215
# 2     3342840
# 3     1506295
# 4    19334329
# 5     2630239
# 0     2630239
# 1     1841615
# 2      478041
# 3      340810
# 4    10045763
# 5     5123362
# 0     5123362
# 1      696428
# 2      806083
# 3     6556862
# 4     3333382
# 5     1558931
# 0     1558931
# 1     1453125
# 2     2233145
# 3     2364097
# 4      679019
# 5     3057895
# 0     3057895
# 1     3455936
# 2     5038598
# 3     2727005
# 4     1536358
# 5     3081445
# 0     3081445
# 1      504536
# 2      939759
# 3     1390901
# 4      670717
# 5     4561386
# 0     4561386
# 1     1051703
# 2    10131373
# 3     5049925
# 4      353677
# 5     5913084
# 0     5913084
# 1     1942789
# 2     1990780
# 3     6534215
# 4     1869213
# 5      543273
# 0      543273
# 1     2455167
# 2      419713
# 3     3331859
# 4    13367298
# 5     1444150
# 0     1444150
# 1      318031
# 2     4195682
# 3     3497739
# 4      937789
# 5     2890732
# dtype: int64

# %%
female_numeric.ffill()
# Out:
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5      679019.0
# 0      679019.0
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1     3081445.0
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 0     1444150.0
# ...

# %%
female_numeric.drop_duplicates()
# Out:
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5           NaN
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 1      318031.0
# 2     4195682.0
# 3     3497739.0
# 4      937789.0
# 5     2890732.0
# Name: femal, dtype: float64

# %%
plt.scatter(female_numeric,df)

# %%
Inventory = pd.read_csv('inventory.csv')

# %%
inventory = pd.DataFrame(Inventory)

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
staten_island = inventory.head(10)

# %%
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request = staten_island['product_description']

# %%
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
inventory[(inventory['location'] == 'Brooklyn') & (inventory['product_type'] == 'seeds')]
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
in_stock = inventory['quantity'] == 0 
inventory['in_stock'] = in_stock

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
total_value = inventory['price'] * inventory['quantity']
inventory['total_value'] = total_value

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
full_description = combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type,
                     row.product_description)
inventory['full_description'] = full_description

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...
